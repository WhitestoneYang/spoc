# %% [markdown]
# ### Lipohilicity dataset
#
# An example of regression task.

# %% [markdown]
# ### 1. Generate descriptors

# %%
# Import necessary packages
# -------------------------
import os
import sys
current_path = os.getcwd()
sys.path.append(current_path)
sys.path.append(os.path.join(sys.path[0], ".."))
from spoc.process import generate_descriptors

# Parameters
# ----------
task_name = "Lipophilicity"

# Download dataset by using the linkage
url = "https://deepchemdata.s3-us-west-1.amazonaws.com/datasets/Lipophilicity.csv"

# Data folder
data_file = "../data/sample_data/Lipophilicity.csv"
feature_file = "./features/all_descriptor_set--Lipophilicity.pkl.zip"

# SMILES column
smiles_col = "smiles"

# If the test_mode="test", then a small amount of data will be used for test.
test_mode = "production"

# Descriptor generation
# ---------------------
# The generated descriptors will be stored with *.pkl.zip format in ./features/
generate_descriptors.load_data(
    task_name, url, data_file, feature_file, smiles_col, test_mode)

# %% [markdown]
# #### 2. Descriptor screening
# Evaluate the performance of various descriptors by using random forest.

# %%
# Import necessary packages
# -------------------------
import pandas as pd
import numpy as np
import os
import sys
current_path = os.getcwd()
sys.path.append(current_path)
sys.path.append(os.path.join(sys.path[0], ".."))
from spoc.process import generate_dataset
from spoc.model import rf

import importlib
importlib.reload(rf)

# Parameters
# ----------
# Data folder
data_file = "../data/sample_data/Lipophilicity.csv"
feature_file = "./features/all_descriptor_set--Lipophilicity.pkl.zip"
output_file = "./output/rf_SF_opt--Lipophilicity.csv"

# The data column of target y
task_col = "exp"

# The data column of SMILES
smiles_col = "smiles"

# Data splitting mode, including:
# RandomSplitter, ScaffoldSplitter, SingletaskStratifiedSplitter
# The recommended splitting mode can be used by refering the published paper.
split_mode = "RandomSplitter"

# Random seed.
# In this case, 5 random seeds are generated by 5 repeated tests.
rnds = range(0, 500, 100)

# Random seed for model training.
model_rnd = 42

# Load descriptor set & dataset
# -----------------------------
data_df, desc_set_df = generate_dataset.load_dataset(data_file, feature_file)
print(f"data_df.shape: {data_df.shape}")
print(f"desc_set_df.shape: {desc_set_df.shape}")

# Model traning
# Screening the performance of all descriptors
#---------------------------------------------
# Feature list
feature_types = desc_set_df.columns
print(f"feature_types: {feature_types}")
# Random forest
# Hyper parameters of regression task.
n_estimators, criterion, max_features, max_depth = 100, 'squared_error', 'auto', 100

result = []
for i, feat_type in enumerate(feature_types):

    print(f"{'-'*30}")
    print(f"{i}th task: {feat_type}")

    mae_test_list, rmse_test_list, r2_test_list = [], [], []
    for rnd in rnds:

        # Read dataset
        X_train, X_test, y_train, y_test = generate_dataset.single_descriptor(
            data_df, desc_set_df, smiles_col, task_col, feat_type, split_mode=split_mode, frac_train=0.9, rnd=42)

        # Model training
        criteria = rf.rf_reg(X_train, X_test, y_train, y_test, n_estimators, criterion, max_features, max_depth, rnd=model_rnd)
        
        rmse_test = criteria['rmse_test']
        mae_test = criteria['mae_test']
        r2_test = criteria['r2_test']
        
        rmse_test_list.append(rmse_test)
        mae_test_list.append(mae_test)
        r2_test_list.append(r2_test)

        mae_test_ave = round(np.average(mae_test_list), 3)
        rmse_test_ave = round(np.average(rmse_test_list), 3)
        r2_test_ave = round(np.average(r2_test_list), 3)
        mae_test_std = round(np.std(mae_test_list), 3)
        rmse_test_std = round(np.std(rmse_test_list), 3)
        r2_test_std = round(np.std(r2_test_list), 3)

    result.append([feat_type, n_estimators, criterion, max_features, max_depth, str(mae_test_list), str(rmse_test_list), str(
        r2_test_list), mae_test_ave, rmse_test_ave, r2_test_ave, mae_test_std, rmse_test_std, r2_test_std])

df = pd.DataFrame(result, columns=['feat_type', 'n_estimators', 'criterion', 'max_features', 'max_depth', 'mae_test_list',
                  'rmse_test_list', 'r2_test_list', 'mae_test_ave', 'rmse_test_ave', 'r2_test_ave', 'mae_test_std', 'rmse_test_std', 'r2_test_std'])
# Save the results
df.to_csv(output_file)
# Out:
# data_df.shape: (4200, 3)
# desc_set_df.shape: (4200, 277)
# feature_types: Index(['Mordred', 'PubChem', 'MACCSKeys', 'RDKitDescriptors', 'klekota-roth',
#        'Estate', 'EstateIndices', 'shortestpath_size512',
#        'shortestpath_size1024', 'shortestpath_size2048',
#        ...
#        'FeaturedMorgan_radius6_size512', 'FeaturedMorgan_radius6_size1024',
#        'FeaturedMorgan_radius6_size2048', 'FeaturedMorgan_radius6_size3072',
#        'FeaturedMorgan_radius6_size4096', 'FeaturedMorgan_radius8_size512',
#        'FeaturedMorgan_radius8_size1024', 'FeaturedMorgan_radius8_size2048',
#        'FeaturedMorgan_radius8_size3072', 'FeaturedMorgan_radius8_size4096'],
#       dtype='object', length=277)
# ------------------------------
# 0th task: Mordred
# ------------------------------
# 1th task: PubChem
# ------------------------------
# 2th task: MACCSKeys
# ------------------------------
# 3th task: RDKitDescriptors
# ------------------------------
# 4th task: klekota-roth
# ------------------------------
# 5th task: Estate
# ------------------------------
# 6th task: EstateIndices
# ------------------------------
# 7th task: shortestpath_size512
# ------------------------------
# 8th task: shortestpath_size1024
# ------------------------------
# 9th task: shortestpath_size2048
# ------------------------------
# 10th task: shortestpath_size3072
# ------------------------------
# 11th task: shortestpath_size4096
# ------------------------------
# 12th task: AtomPaires_size512
# ------------------------------
# 13th task: AtomPaires_size1024
# ------------------------------
# 14th task: AtomPaires_size2048
# ------------------------------
# 15th task: AtomPaires_size3072
# ------------------------------
# 16th task: AtomPaires_size4096
# ------------------------------
# 17th task: Avalon_size512
# ------------------------------
# 18th task: Avalon_size1024
# ------------------------------
# 19th task: Avalon_size2048
# ------------------------------
# 20th task: Avalon_size3072
# ------------------------------
# 21th task: Avalon_size4096
# ------------------------------
# 22th task: TopologicalTorsions_size512
# ------------------------------
# 23th task: TopologicalTorsions_size1024
# ------------------------------
# 24th task: TopologicalTorsions_size2048
# ------------------------------
# 25th task: TopologicalTorsions_size3072
# ------------------------------
# 26th task: TopologicalTorsions_size4096
# ------------------------------
# 27th task: FP2_size512
# ------------------------------
# 28th task: FP2_size1024
# ------------------------------
# 29th task: FP2_size2048
# ------------------------------
# 30th task: FP2_size3072
# ------------------------------
# 31th task: FP2_size4096
# ------------------------------
# 32th task: FP3_size512
# ------------------------------
# 33th task: FP3_size1024
# ------------------------------
# 34th task: FP3_size2048
# ------------------------------
# 35th task: FP3_size3072
# ------------------------------
# 36th task: FP3_size4096
# ------------------------------
# 37th task: FP4_size512
# ------------------------------
# 38th task: FP4_size1024
# ------------------------------
# 39th task: FP4_size2048
# ------------------------------
# 40th task: FP4_size3072
# ------------------------------
# 41th task: FP4_size4096
# ------------------------------
# 42th task: lingo_max_depth0
# ------------------------------
# 43th task: lingo_max_depth2
# ------------------------------
# 44th task: lingo_max_depth4
# ------------------------------
# 45th task: lingo_max_depth6
# ------------------------------
# 46th task: lingo_max_depth8
# ------------------------------
# 47th task: signature_max_depth0
# ------------------------------
# 48th task: signature_max_depth2
# ------------------------------
# 49th task: signature_max_depth4
# ------------------------------
# 50th task: signature_max_depth6
# ------------------------------
# 51th task: signature_max_depth8
# ------------------------------
# 52th task: daylight_max_depth0_size512
# ------------------------------
# 53th task: daylight_max_depth0_size1024
# ------------------------------
# 54th task: daylight_max_depth0_size2048
# ------------------------------
# 55th task: daylight_max_depth0_size3072
# ------------------------------
# 56th task: daylight_max_depth0_size4096
# ------------------------------
# 57th task: daylight_max_depth2_size512
# ------------------------------
# 58th task: daylight_max_depth2_size1024
# ------------------------------
# 59th task: daylight_max_depth2_size2048
# ------------------------------
# 60th task: daylight_max_depth2_size3072
# ------------------------------
# 61th task: daylight_max_depth2_size4096
# ------------------------------
# 62th task: daylight_max_depth4_size512
# ------------------------------
# 63th task: daylight_max_depth4_size1024
# ------------------------------
# 64th task: daylight_max_depth4_size2048
# ------------------------------
# 65th task: daylight_max_depth4_size3072
# ------------------------------
# 66th task: daylight_max_depth4_size4096
# ------------------------------
# 67th task: daylight_max_depth6_size512
# ------------------------------
# 68th task: daylight_max_depth6_size1024
# ------------------------------
# 69th task: daylight_max_depth6_size2048
# ------------------------------
# 70th task: daylight_max_depth6_size3072
# ------------------------------
# 71th task: daylight_max_depth6_size4096
# ------------------------------
# 72th task: daylight_max_depth8_size512
# ------------------------------
# 73th task: daylight_max_depth8_size1024
# ------------------------------
# 74th task: daylight_max_depth8_size2048
# ------------------------------
# 75th task: daylight_max_depth8_size3072
# ------------------------------
# 76th task: daylight_max_depth8_size4096
# ------------------------------
# 77th task: extended_max_depth0_size512
# ------------------------------
# 78th task: extended_max_depth0_size1024
# ------------------------------
# 79th task: extended_max_depth0_size2048
# ------------------------------
# 80th task: extended_max_depth0_size3072
# ------------------------------
# 81th task: extended_max_depth0_size4096
# ------------------------------
# 82th task: extended_max_depth2_size512
# ------------------------------
# 83th task: extended_max_depth2_size1024
# ------------------------------
# 84th task: extended_max_depth2_size2048
# ------------------------------
# 85th task: extended_max_depth2_size3072
# ------------------------------
# 86th task: extended_max_depth2_size4096
# ------------------------------
# 87th task: extended_max_depth4_size512
# ------------------------------
# 88th task: extended_max_depth4_size1024
# ------------------------------
# 89th task: extended_max_depth4_size2048
# ------------------------------
# 90th task: extended_max_depth4_size3072
# ------------------------------
# 91th task: extended_max_depth4_size4096
# ------------------------------
# 92th task: extended_max_depth6_size512
# ------------------------------
# 93th task: extended_max_depth6_size1024
# ------------------------------
# 94th task: extended_max_depth6_size2048
# ------------------------------
# 95th task: extended_max_depth6_size3072
# ------------------------------
# 96th task: extended_max_depth6_size4096
# ------------------------------
# 97th task: extended_max_depth8_size512
# ------------------------------
# 98th task: extended_max_depth8_size1024
# ------------------------------
# 99th task: extended_max_depth8_size2048
# ------------------------------
# 100th task: extended_max_depth8_size3072
# ------------------------------
# 101th task: extended_max_depth8_size4096
# ------------------------------
# 102th task: graph_max_depth0_size512
# ------------------------------
# 103th task: graph_max_depth0_size1024
# ------------------------------
# 104th task: graph_max_depth0_size2048
# ------------------------------
# 105th task: graph_max_depth0_size3072
# ------------------------------
# 106th task: graph_max_depth0_size4096
# ------------------------------
# 107th task: graph_max_depth2_size512
# ------------------------------
# 108th task: graph_max_depth2_size1024
# ------------------------------
# 109th task: graph_max_depth2_size2048
# ------------------------------
# 110th task: graph_max_depth2_size3072
# ------------------------------
# 111th task: graph_max_depth2_size4096
# ------------------------------
# 112th task: graph_max_depth4_size512
# ------------------------------
# 113th task: graph_max_depth4_size1024
# ------------------------------
# 114th task: graph_max_depth4_size2048
# ------------------------------
# 115th task: graph_max_depth4_size3072
# ------------------------------
# 116th task: graph_max_depth4_size4096
# ------------------------------
# 117th task: graph_max_depth6_size512
# ------------------------------
# 118th task: graph_max_depth6_size1024
# ------------------------------
# 119th task: graph_max_depth6_size2048
# ------------------------------
# 120th task: graph_max_depth6_size3072
# ------------------------------
# 121th task: graph_max_depth6_size4096
# ------------------------------
# 122th task: graph_max_depth8_size512
# ------------------------------
# 123th task: graph_max_depth8_size1024
# ------------------------------
# 124th task: graph_max_depth8_size2048
# ------------------------------
# 125th task: graph_max_depth8_size3072
# ------------------------------
# 126th task: graph_max_depth8_size4096
# ------------------------------
# 127th task: hybridization_max_depth0_size512
# ------------------------------
# 128th task: hybridization_max_depth0_size1024
# ------------------------------
# 129th task: hybridization_max_depth0_size2048
# ------------------------------
# 130th task: hybridization_max_depth0_size3072
# ------------------------------
# 131th task: hybridization_max_depth0_size4096
# ------------------------------
# 132th task: hybridization_max_depth2_size512
# ------------------------------
# 133th task: hybridization_max_depth2_size1024
# ------------------------------
# 134th task: hybridization_max_depth2_size2048
# ------------------------------
# 135th task: hybridization_max_depth2_size3072
# ------------------------------
# 136th task: hybridization_max_depth2_size4096
# ------------------------------
# 137th task: hybridization_max_depth4_size512
# ------------------------------
# 138th task: hybridization_max_depth4_size1024
# ------------------------------
# 139th task: hybridization_max_depth4_size2048
# ------------------------------
# 140th task: hybridization_max_depth4_size3072
# ------------------------------
# 141th task: hybridization_max_depth4_size4096
# ------------------------------
# 142th task: hybridization_max_depth6_size512
# ------------------------------
# 143th task: hybridization_max_depth6_size1024
# ------------------------------
# 144th task: hybridization_max_depth6_size2048
# ------------------------------
# 145th task: hybridization_max_depth6_size3072
# ------------------------------
# 146th task: hybridization_max_depth6_size4096
# ------------------------------
# 147th task: hybridization_max_depth8_size512
# ------------------------------
# 148th task: hybridization_max_depth8_size1024
# ------------------------------
# 149th task: hybridization_max_depth8_size2048
# ------------------------------
# 150th task: hybridization_max_depth8_size3072
# ------------------------------
# 151th task: hybridization_max_depth8_size4096
# ------------------------------
# 152th task: RDKit_max_depth0_size512
# ------------------------------
# 153th task: RDKit_max_depth0_size1024
# ------------------------------
# 154th task: RDKit_max_depth0_size2048
# ------------------------------
# 155th task: RDKit_max_depth0_size3072
# ------------------------------
# 156th task: RDKit_max_depth0_size4096
# ------------------------------
# 157th task: RDKit_max_depth2_size512
# ------------------------------
# 158th task: RDKit_max_depth2_size1024
# ------------------------------
# 159th task: RDKit_max_depth2_size2048
# ------------------------------
# 160th task: RDKit_max_depth2_size3072
# ------------------------------
# 161th task: RDKit_max_depth2_size4096
# ------------------------------
# 162th task: RDKit_max_depth4_size512
# ------------------------------
# 163th task: RDKit_max_depth4_size1024
# ------------------------------
# 164th task: RDKit_max_depth4_size2048
# ------------------------------
# 165th task: RDKit_max_depth4_size3072
# ------------------------------
# 166th task: RDKit_max_depth4_size4096
# ------------------------------
# 167th task: RDKit_max_depth6_size512
# ------------------------------
# 168th task: RDKit_max_depth6_size1024
# ------------------------------
# 169th task: RDKit_max_depth6_size2048
# ------------------------------
# 170th task: RDKit_max_depth6_size3072
# ------------------------------
# 171th task: RDKit_max_depth6_size4096
# ------------------------------
# 172th task: RDKit_max_depth8_size512
# ------------------------------
# 173th task: RDKit_max_depth8_size1024
# ------------------------------
# 174th task: RDKit_max_depth8_size2048
# ------------------------------
# 175th task: RDKit_max_depth8_size3072
# ------------------------------
# 176th task: RDKit_max_depth8_size4096
# ------------------------------
# 177th task: RDKitLinear_max_depth0_size512
# ------------------------------
# 178th task: RDKitLinear_max_depth0_size1024
# ------------------------------
# 179th task: RDKitLinear_max_depth0_size2048
# ------------------------------
# 180th task: RDKitLinear_max_depth0_size3072
# ------------------------------
# 181th task: RDKitLinear_max_depth0_size4096
# ------------------------------
# 182th task: RDKitLinear_max_depth2_size512
# ------------------------------
# 183th task: RDKitLinear_max_depth2_size1024
# ------------------------------
# 184th task: RDKitLinear_max_depth2_size2048
# ------------------------------
# 185th task: RDKitLinear_max_depth2_size3072
# ------------------------------
# 186th task: RDKitLinear_max_depth2_size4096
# ------------------------------
# 187th task: RDKitLinear_max_depth4_size512
# ------------------------------
# 188th task: RDKitLinear_max_depth4_size1024
# ------------------------------
# 189th task: RDKitLinear_max_depth4_size2048
# ------------------------------
# 190th task: RDKitLinear_max_depth4_size3072
# ------------------------------
# 191th task: RDKitLinear_max_depth4_size4096
# ------------------------------
# 192th task: RDKitLinear_max_depth6_size512
# ------------------------------
# 193th task: RDKitLinear_max_depth6_size1024
# ------------------------------
# 194th task: RDKitLinear_max_depth6_size2048
# ------------------------------
# 195th task: RDKitLinear_max_depth6_size3072
# ------------------------------
# 196th task: RDKitLinear_max_depth6_size4096
# ------------------------------
# 197th task: RDKitLinear_max_depth8_size512
# ------------------------------
# 198th task: RDKitLinear_max_depth8_size1024
# ------------------------------
# 199th task: RDKitLinear_max_depth8_size2048
# ------------------------------
# 200th task: RDKitLinear_max_depth8_size3072
# ------------------------------
# 201th task: RDKitLinear_max_depth8_size4096
# ------------------------------
# 202th task: LayeredFingerprint_max_depth0_size512
# ------------------------------
# 203th task: LayeredFingerprint_max_depth0_size1024
# ------------------------------
# 204th task: LayeredFingerprint_max_depth0_size2048
# ------------------------------
# 205th task: LayeredFingerprint_max_depth0_size3072
# ------------------------------
# 206th task: LayeredFingerprint_max_depth0_size4096
# ------------------------------
# 207th task: LayeredFingerprint_max_depth2_size512
# ------------------------------
# 208th task: LayeredFingerprint_max_depth2_size1024
# ------------------------------
# 209th task: LayeredFingerprint_max_depth2_size2048
# ------------------------------
# 210th task: LayeredFingerprint_max_depth2_size3072
# ------------------------------
# 211th task: LayeredFingerprint_max_depth2_size4096
# ------------------------------
# 212th task: LayeredFingerprint_max_depth4_size512
# ------------------------------
# 213th task: LayeredFingerprint_max_depth4_size1024
# ------------------------------
# 214th task: LayeredFingerprint_max_depth4_size2048
# ------------------------------
# 215th task: LayeredFingerprint_max_depth4_size3072
# ------------------------------
# 216th task: LayeredFingerprint_max_depth4_size4096
# ------------------------------
# 217th task: LayeredFingerprint_max_depth6_size512
# ------------------------------
# 218th task: LayeredFingerprint_max_depth6_size1024
# ------------------------------
# 219th task: LayeredFingerprint_max_depth6_size2048
# ------------------------------
# 220th task: LayeredFingerprint_max_depth6_size3072
# ------------------------------
# 221th task: LayeredFingerprint_max_depth6_size4096
# ------------------------------
# 222th task: LayeredFingerprint_max_depth8_size512
# ------------------------------
# 223th task: LayeredFingerprint_max_depth8_size1024
# ------------------------------
# 224th task: LayeredFingerprint_max_depth8_size2048
# ------------------------------
# 225th task: LayeredFingerprint_max_depth8_size3072
# ------------------------------
# 226th task: LayeredFingerprint_max_depth8_size4096
# ------------------------------
# 227th task: Morgan_radius0_size512
# ------------------------------
# 228th task: Morgan_radius0_size1024
# ------------------------------
# 229th task: Morgan_radius0_size2048
# ------------------------------
# 230th task: Morgan_radius0_size3072
# ------------------------------
# 231th task: Morgan_radius0_size4096
# ------------------------------
# 232th task: Morgan_radius2_size512
# ------------------------------
# 233th task: Morgan_radius2_size1024
# ------------------------------
# 234th task: Morgan_radius2_size2048
# ------------------------------
# 235th task: Morgan_radius2_size3072
# ------------------------------
# 236th task: Morgan_radius2_size4096
# ------------------------------
# 237th task: Morgan_radius4_size512
# ------------------------------
# 238th task: Morgan_radius4_size1024
# ------------------------------
# 239th task: Morgan_radius4_size2048
# ------------------------------
# 240th task: Morgan_radius4_size3072
# ------------------------------
# 241th task: Morgan_radius4_size4096
# ------------------------------
# 242th task: Morgan_radius6_size512
# ------------------------------
# 243th task: Morgan_radius6_size1024
# ------------------------------
# 244th task: Morgan_radius6_size2048
# ------------------------------
# 245th task: Morgan_radius6_size3072
# ------------------------------
# 246th task: Morgan_radius6_size4096
# ------------------------------
# 247th task: Morgan_radius8_size512
# ------------------------------
# 248th task: Morgan_radius8_size1024
# ------------------------------
# 249th task: Morgan_radius8_size2048
# ------------------------------
# 250th task: Morgan_radius8_size3072
# ------------------------------
# 251th task: Morgan_radius8_size4096
# ------------------------------
# 252th task: FeaturedMorgan_radius0_size512
# ------------------------------
# 253th task: FeaturedMorgan_radius0_size1024
# ------------------------------
# 254th task: FeaturedMorgan_radius0_size2048
# ------------------------------
# 255th task: FeaturedMorgan_radius0_size3072
# ------------------------------
# 256th task: FeaturedMorgan_radius0_size4096
# ------------------------------
# 257th task: FeaturedMorgan_radius2_size512
# ------------------------------
# 258th task: FeaturedMorgan_radius2_size1024
# ------------------------------
# 259th task: FeaturedMorgan_radius2_size2048
# ------------------------------
# 260th task: FeaturedMorgan_radius2_size3072
# ------------------------------
# 261th task: FeaturedMorgan_radius2_size4096
# ------------------------------
# 262th task: FeaturedMorgan_radius4_size512
# ------------------------------
# 263th task: FeaturedMorgan_radius4_size1024
# ------------------------------
# 264th task: FeaturedMorgan_radius4_size2048
# ------------------------------
# 265th task: FeaturedMorgan_radius4_size3072
# ------------------------------
# 266th task: FeaturedMorgan_radius4_size4096
# ------------------------------
# 267th task: FeaturedMorgan_radius6_size512
# ------------------------------
# 268th task: FeaturedMorgan_radius6_size1024
# ------------------------------
# 269th task: FeaturedMorgan_radius6_size2048
# ------------------------------
# 270th task: FeaturedMorgan_radius6_size3072
# ------------------------------
# 271th task: FeaturedMorgan_radius6_size4096
# ------------------------------
# 272th task: FeaturedMorgan_radius8_size512
# ------------------------------
# 273th task: FeaturedMorgan_radius8_size1024
# ------------------------------
# 274th task: FeaturedMorgan_radius8_size2048
# ------------------------------
# 275th task: FeaturedMorgan_radius8_size3072
# ------------------------------
# 276th task: FeaturedMorgan_radius8_size4096

# %% [markdown]
# #### 3. SPOC screening
# Evaluate the performance of various S+POC combination by using random forest.m

# %%
# Import necessary packages
# -------------------------
import pandas as pd
import numpy as np
import os
import sys
current_path = os.getcwd()
sys.path.append(current_path)
sys.path.append(os.path.join(sys.path[0], ".."))
from spoc.process import generate_dataset
from spoc.model import rf

import importlib
importlib.reload(generate_dataset)
importlib.reload(rf)

# Parameters
# ----------
# Data folder
data_file = "../data/sample_data/Lipophilicity.csv"
feature_file = "./features/all_descriptor_set--Lipophilicity.pkl.zip"
rf_SF_opt_file = "./output/rf_SF_opt--Lipophilicity.csv"
output_file = "./output/rf_SPOC_opt--Lipophilicity.csv"

# target y value
task_col = "exp"

# SMILES column
smiles_col = "smiles"

# Data splitting mode
split_mode = "RandomSplitter"

# The criteria used for descriptor evaluation
# In this case, rmse serves as the criteria
criterion_col = "rmse_test_ave"

# Performance sort order, smaller is better for rmse, so ascending=True  
ascending = True

# Random seed
rnds = range(0, 500, 100)

# Model random seed
model_rnd = 42

# Load descriptor set & dataset
# -----------------------------
data_df, desc_set_df = generate_dataset.load_dataset(data_file, feature_file)
print(f"data_df.shape: {data_df.shape}")
print(f"desc_set_df.shape: {desc_set_df.shape}")

# 20 best S+POC combination
# --------------------------
# exclude ['Mordred','RDKitDescriptors']
df = df[~df['feat_type'].isin(['Mordred','RDKitDescriptors'])]

# RMSE: smaller is better
df = df.sort_values(by=[criterion_col], axis=0, ascending=ascending)

# Choose the best 20 fingerprint 
df = df.iloc[:20,:]
feature_type_Ss = df['feat_type'].values
print(f"20 best feature_Ss: {feature_type_Ss}")
feature_type_POCs = ['Mordred','RDKitDescriptors']
print(f"feature_POCs: {feature_type_POCs}")

# Model traning
# Screening the performance of all descriptors
#---------------------------------------------
# feature list
feature_types = desc_set_df.columns
print(f"feature_types: {feature_types}")

# Random forest
# Hyper parameters of regression
n_estimators, criterion, max_features, max_depth = 100, 'squared_error', 'auto', 100

result = []
for i, feat_type_S in enumerate(feature_type_Ss):
    for j, feat_type_POC in enumerate(feature_type_POCs):
        print(f"{'-'*30}")
        print(f"{i}th task: {feat_type}")

        mae_test_list, rmse_test_list, r2_test_list = [], [], []
        for rnd in rnds:
            
            # Load dataset
            X_train, X_test, y_train, y_test = generate_dataset.SPOC_descriptor(data_df, desc_set_df, smiles_col, task_col, feat_type_S, feat_type_POC, split_mode, frac_train=0.9, rnd=42)

            # Model training
            criteria = rf.rf_reg(
                X_train, X_test, y_train, y_test, n_estimators, criterion, max_features, max_depth, rnd=model_rnd)
            
            rmse_test = criteria['rmse_test']
            mae_test = criteria['mae_test']
            r2_test = criteria['r2_test']
                   
            rmse_test_list.append(rmse_test)
            mae_test_list.append(mae_test)
            r2_test_list.append(r2_test)

        mae_test_ave = round(np.average(mae_test_list), 3)
        rmse_test_ave = round(np.average(rmse_test_list), 3)
        r2_test_ave = round(np.average(r2_test_list), 3)
        mae_test_std = round(np.std(mae_test_list), 3)
        rmse_test_std = round(np.std(rmse_test_list), 3)
        r2_test_std = round(np.std(r2_test_list), 3)

        result.append([feat_type_S, feat_type_POC, n_estimators, criterion, max_features, max_depth, str(mae_test_list), str(rmse_test_list), str(
            r2_test_list), mae_test_ave, rmse_test_ave, r2_test_ave, mae_test_std, rmse_test_std, r2_test_std])

print(result)
df = pd.DataFrame(result, columns=['feat_type_S', 'feat_type_POC', 'n_estimators', 'criterion', 'max_features', 'max_depth', 'mae_test_list', 'rmse_test_list', 'r2_test_list', 'mae_test_ave', 'rmse_test_ave', 'r2_test_ave', 'mae_test_std', 'rmse_test_std', 'r2_test_std'])

# Save the results
df.to_csv(output_file)

# %% [markdown]
# #### 4. Bayes Optimization by using LightGBM

# %%
# Import necessary packages
# -------------------------
import pandas as pd
import numpy as np
import os
import sys
current_path = os.getcwd()
sys.path.append(current_path)
sys.path.append(os.path.join(sys.path[0], ".."))
from spoc.model import lightgbm
from spoc.process import generate_dataset

import importlib
importlib.reload(generate_dataset)
importlib.reload(lightgbm)

# Parameters
# ----------
# Data folder
data_file = "../data/sample_data/Lipophilicity.csv"
feature_file = "./features/all_descriptor_set--Lipophilicity.pkl.zip"
rf_SPOC_opt_file = "./output/rf_SPOC_opt--Lipophilicity.csv"
output_file = "./output/lgb_SPOC_opt--Lipophilicity.csv"

# target y value
task_col = "exp"

# SMILES column
smiles_col = "smiles"

# Data splitting mode
split_mode = "RandomSplitter"

# The criteria used for descriptor evaluation
# In this case, rmse serves as the criteria
criterion_col = "rmse_test_ave"

# Performance sort order, smaller is better for rmse, so ascending=True 
ascending = True

# Random seed
rnds = range(0, 500, 100)

# Model random seed
model_rnd = 42

# Task type
task_type = "regression"

# Bayes Optimization
# Initial iteration, more is better
init_iter = 3

# Optimization times, more is better
n_iters = 5

# LightGBM score function
feval, ascending = lightgbm.feval_value(criterion_col)

# Load descriptor set & dataset
# -----------------------------
data_df, desc_set_df = generate_dataset.load_dataset(data_file, feature_file)
data_df = data_df.iloc[0:100, :]
print(f"data_df.shape: {data_df.shape}")
print(f"desc_set_df.shape: {desc_set_df.shape}")

# Best S+POC combination
# --------------------------
df = pd.read_csv(rf_SPOC_opt_file)
df = df.sort_values(by=[criterion_col], axis=0, ascending=ascending)
feat_type_S = df['feat_type_S'].values[0]
feat_type_POC = df['feat_type_POC'].values[0]
print(f"Best S+POCs combination: {feat_type_S} + {feat_type_POC}")

# Start hyper opt:
#------------------------------------------
mae_test_list, rmse_test_list, r2_test_list = [], [], []
result = []
for seed in rnds:
    # Load data
    X_train, X_test, y_train, y_test = generate_dataset.SPOC_descriptor(data_df, desc_set_df, smiles_col, task_col, feat_type_S, feat_type_POC, split_mode, frac_train=0.9, rnd=42)

    print(f"X_train.shape: {X_train.shape}, X_test.shape: {X_test.shape}, y_train.shape: {y_train.shape}, y_test.shape: {y_test.shape}")

    # Optimization
    best_params = lightgbm.bayesopt_lgb(X_train, y_train, init_iter, n_iters, feval, criterion_col, pds='default', random_state=model_rnd, seed=seed, task=task_type)

    # Model training
    criteria = lightgbm.lgb_train(X_train, X_test, y_train, y_test, best_params, feval, seed=seed, task="regression")
    rmse_test = criteria['rmse_test']
    mae_test = criteria['rmse_test']
    r2_test = criteria['r2_test']
    
    mae_test_list.append(mae_test)
    rmse_test_list.append(rmse_test)
    r2_test_list.append(r2_test)

    temp_result = [seed, mae_test, rmse_test, r2_test, best_params]
    result.append(temp_result)

# Summary
mae_test_ave = np.average(mae_test_list)
rmse_test_ave = np.average(rmse_test_list)
r2_test_ave = np.average(r2_test_list)
mae_test_std = np.std(mae_test_list)
rmse_test_std = np.std(rmse_test_list)
r2_test_std = np.std(r2_test_list)

result.append(["ave", mae_test_ave, rmse_test_ave, r2_test_ave, "--"])
result.append(["std", mae_test_std, rmse_test_std, r2_test_std, "--"])

# Save results
# --------------
df = pd.DataFrame(result, columns=['entry', 'mae_test_ave', 'rmse_test_ave', 'r2_test_ave', 'best-params'])
df.to_csv(output_file)

# %% [markdown]
# #### 5. Bayes Optimization with XGBoost

# %%
# Import necessary packages
# -------------------------
import pandas as pd
import numpy as np
import os
import sys
current_path = os.getcwd()
sys.path.append(current_path)
sys.path.append(os.path.join(sys.path[0], ".."))
from spoc.model import xgboost
from spoc.process import generate_dataset

import importlib
importlib.reload(xgboost)
importlib.reload(generate_dataset)

# Parameters
# ----------
# Data folder
data_file = "../data/sample_data/Lipophilicity.csv"
feature_file = "./features/all_descriptor_set--Lipophilicity.pkl.zip"
rf_SPOC_opt_file = "./output/rf_SPOC_opt--Lipophilicity.csv"
output_file = "./output/xgb_SPOC_opt--Lipophilicity.csv"

# target y value
task_col = "exp"

# SMILES column
smiles_col = "smiles"

# Data splitting mode
split_mode = "RandomSplitter"

# The criteria used for descriptor evaluation
# In this case, rmse serves as the criteria
criterion_col = "rmse_test_ave"

# Performance sort order, smaller is better for rmse, so ascending=True 
ascending = True

# Random seed
rnds = range(0, 500, 100)

# Bayes Optimization
# Initial iteration, more is better
init_iter = 3

# Optimization times, more is better
n_iters = 5

# Task type
task_type = "regression"

# Model random seed
model_rnd = 42

# load descriptor set & dataset
# -----------------------------
data_df, desc_set_df = generate_dataset.load_dataset(data_file, feature_file)
print(f"data_df.shape: {data_df.shape}")
print(f"desc_set_df.shape: {desc_set_df.shape}")

# Best S+POC combination
# --------------------------
df = pd.read_csv(rf_SPOC_opt_file)
df = df.sort_values(by=[criterion_col], axis=0, ascending=ascending)
feat_type_S = df['feat_type_S'].values[0]
feat_type_POC = df['feat_type_POC'].values[0]
print(f"Best S+POCs combination: {feat_type_S} + {feat_type_POC}")

# XGBoost score function
feval, ascending = xgboost.feval_value(criterion_col)

# Start hyper opt:
#------------------------------------------
mae_test_list, rmse_test_list, r2_test_list = [], [], []
result = []
for seed in rnds:
    # Load data
    X_train, X_test, y_train, y_test = generate_dataset.SPOC_descriptor(data_df, desc_set_df, smiles_col, task_col, feat_type_S, feat_type_POC, split_mode, frac_train=0.9, rnd=42)

    print(f"X_train.shape: {X_train.shape}, X_test.shape: {X_test.shape}, y_train.shape: {y_train.shape}, y_test.shape: {y_test.shape}")

    # Optimization
    best_params = xgboost.bayesion_opt_xgb(X_train, y_train, task_type, init_iter, n_iters, feval, criterion_col, pds='default', random_state=model_rnd, seed=seed)
    
    # Model training
    criteria = xgboost.xgb_train(X_train, X_test, y_train, y_test, task_type, best_params, feval)
    rmse_test = criteria['rmse_test']
    mae_test = criteria['rmse_test']
    r2_test = criteria['r2_test']
    
    mae_test_list.append(mae_test)
    rmse_test_list.append(rmse_test)
    r2_test_list.append(r2_test)

    temp_result = [seed, mae_test, rmse_test, r2_test, best_params]
    result.append(temp_result)

# Summary
mae_test_ave = np.average(mae_test_list)
rmse_test_ave = np.average(rmse_test_list)
r2_test_ave = np.average(r2_test_list)
mae_test_std = np.std(mae_test_list)
rmse_test_std = np.std(rmse_test_list)
r2_test_std = np.std(r2_test_list)

result.append(["ave", mae_test_ave, rmse_test_ave, r2_test_ave, "--"])
result.append(["std", mae_test_std, rmse_test_std, r2_test_std, "--"])

# Save results
# --------------
df = pd.DataFrame(result, columns=['entry', 'mae_test_ave', 'rmse_test_ave', 'r2_test_ave', 'best-params'])
df.to_csv(output_file)
